# %%
# import necessary Libraries
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import tree
from sklearn.linear_model import LinearRegression, LogisticRegression, LogisticRegressionCV, Ridge
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, GridSearchCV, ShuffleSplit
from sklearn import feature_selection as fs
from scipy import stats
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
abalone = pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
abalone.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
abalone.tail(5)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
abl = abalone.copy()
abl
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
abl.describe(include = ['int64','float64'])
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# Though features are not normaly distributed, are close to normality Each feature has difference scale range None of the features have minimum = 0 except Height (requires re-check)

# %%
# check height ==0
(abl.Height ==0).sum()
# Out:
# 2

# %% [markdown]
# column height has 2 zero value

# %%
abl[abl['Height']==0]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1257   I   0.430      0.34     0.0         0.428          0.2065
# 3996   I   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera weight  Shell weight  Rings
# 1257          0.0860        0.1150      8
# 3996          0.0285        0.3505      6

# %% [markdown]
# number of missing values is 2 and is in the infant sex.
#
# We will fill in the missing value with the average Height feature for the immature gender

# %%
mean = pd.pivot_table(abl,index=['Sex'],aggfunc={'Height':np.mean})
mean
# Out:
#        Height
# Sex
# F    0.158011
# I    0.107996
# M    0.151381

# %%
abl['Height'] = abl['Height'].replace(to_replace=0,value =0.107996 )
#checking NaN values in the datadet.

abl.isnull().sum(axis=0)
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# EDA (Exploratory Data Analysis)

# %%
# Dimension of dataset

print(abl.shape)

print("No. of rows : ", abl.shape[0])
print("No. of columns : ", abl.shape[1])
# Out:
# (4177, 9)
# No. of rows :  4177
# No. of columns :  9

# %%
# unique values
abalone.nunique()
# Out:
# Sex                  3
# Length             134
# Diameter           111
# Height              51
# Whole weight      2429
# Shucked weight    1515
# Viscera weight     880
# Shell weight       926
# Rings               28
# dtype: int64

# %%
#check duplicate values
abl.duplicated().sum()
# Out:
# 0

# %%
# Relationship between Dependent and Independent variables
x = abl.drop(columns =["Rings"])
y = abl['Rings']
# Analyzing the Target Variable
abl['Rings'].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %%
abl['Rings'].nunique()
# Out:
# 28

# %% [markdown]
# There are 28 ring count values in the label column / target variable.

# %%
# Checking number of values in each 28 categories
abl["Rings"].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %%
# checking the same in Graph format
sns.countplot(abl["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# It is observed that the distribution is right skewed with the majority of values falling in the region between '5' to '13' and then the rest values tailing ooff from '14' to '29'
#
# The Data in target / label column is describe in nature since the count of "Rings" range 1 to 29 and the age of Abalone will be determined by adding 1.5 to number of rings.

# %%
# There are 3 categories in column 'Sex' : M,F,I. Checking values count in each categories.
abl['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
#distribution of categorical features
print(abl['Sex'].unique())

sns.countplot(x = 'Sex', data = abl)
# Out:
# ['M' 'F' 'I']
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# Visualising with PIE chart
labels = 'M','F','I'
fig, ax = plt.subplots()
ax.pie(abl['Sex'].value_counts(),labels = labels,radius = 1, autopct = '%1.2f%%', shadow = True)
plt.show()

# %% [markdown]
# We will convert Sex to numerical. Immature may have lower rings
#
#   * M = 36.58%
#   * F = 32.13%
#   * I = 31.29%

# %%
#confirm our observations and our assumptions

abl[['Sex', 'Rings']].groupby('Sex', as_index=False).mean().sort_values(by='Rings', ascending=False)
# Out:
#   Sex      Rings
# 0   F  11.129304
# 2   M  10.705497
# 1   I   7.890462

# %% [markdown]
# Data Visualization

# %%
# corerelation between data using heatmap

plt.figure(figsize = (20,10))
sns.heatmap(abl.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
#plotting sns plot
sns.set()
cols = ['Length','Diameter','Height','Whole weight', 'Shucked weight','Viscera weight', 'Shell weight','Rings']
sns.pairplot(abalone[cols], height = 2.5)
plt.show();

# %% [markdown]
# Categorical Feature

# %%
data = pd.concat([abalone['Rings'], abalone['Sex']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxenplot(x='Sex', y="Rings", data=abalone)
fig.axis(ymin=0, ymax=30);

# %%
#spliting data into target and features

x = abl.drop(columns="Rings")
y = abl['Rings']

# one hot encoding
x = pd.get_dummies(abl)
x.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings', 'Sex_F', 'Sex_I', 'Sex_M'],
#       dtype='object')

# %%
x.shape
# Out:
# (4177, 11)

# %%
y.value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %% [markdown]
# As we can see the classes of target are not balanced.

# %%
# Dropping the values in categorical columns ('M','F','I') since their skewness can not be chaecked.
sk = x.drop(columns=['Sex_F', 'Sex_I', 'Sex_M'], axis = 1)
sk
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# 2           0.2100      9
# 3           0.1550     10
# 4           0.0550      7
# ...            ...    ...
# 4172        0.2490     11
# 4173        0.2605     10
# 4174        0.3080      9
# 4175        0.2960     10
# 4176        0.4950     12
#
# [4177 rows x 8 columns]

# %%
# Visualising data distribution for every column

plt.figure(figsize=(25,30))
plotnum=1

for col in sk:
    if plotnum<=10:
        plt.subplot(5,5,plotnum)
        sns.distplot(x[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
sk.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.166698
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# Outliers Detection

# %%
plt.figure(figsize=(20,25))
plotnum=1

for col in sk:
    if plotnum<=10:
        plt.subplot(5,5,plotnum)
        sns.boxplot(x[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# Z score method to remove outliers

# %%
# taking 3 as threshold
from scipy.stats import zscore
zscore = zscore(sk)
zabs = np.abs(zscore)

out = sk[(zabs<3).all(axis=1)] 
out.shape
# Out:
# (4029, 8)

# %%
sk.shape
# Out:
# (4177, 8)

# %%
# calculating Dataloss in the data set %

loss = (4177-4086)/4177*100
loss
# Out:
# 2.178597079243476

# %%
dropindex = x.index.difference(out.index)
dropindex
# Out:
# Int64Index([   6,   72,   81,   83,  129,  163,  164,  165,  166,  167,
#             ...
#             3837, 3899, 3902, 3924, 3930, 3944, 3961, 3962, 4145, 4148],
#            dtype='int64', length=148)

# %%
sk.drop(dropindex,inplace = True)
sk
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# 2           0.2100      9
# 3           0.1550     10
# 4           0.0550      7
# ...            ...    ...
# 4172        0.2490     11
# 4173        0.2605     10
# 4174        0.3080      9
# 4175        0.2960     10
# 4176        0.4950     12
#
# [4029 rows x 8 columns]

# %%
plt.figure(figsize=(20,25))
plotnum=1

for col in out:
    if plotnum<=10:
        plt.subplot(5,5,plotnum)
        sns.boxplot(out[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# Skewness Removal

# %%
out.skew()
# Out:
# Length           -0.621961
# Diameter         -0.597677
# Height           -0.243246
# Whole weight      0.334719
# Shucked weight    0.458771
# Viscera weight    0.437599
# Shell weight      0.349333
# Rings             0.725901
# dtype: float64

# %%
skew = ['Length','Diameter']

skewddf = out[skew].copy()

skewddf
# Out:
#       Length  Diameter
# 0      0.455     0.365
# 1      0.350     0.265
# 2      0.530     0.420
# 3      0.440     0.365
# 4      0.330     0.255
# ...      ...       ...
# 4172   0.565     0.450
# 4173   0.590     0.440
# 4174   0.600     0.475
# 4175   0.625     0.485
# 4176   0.710     0.555
#
# [4029 rows x 2 columns]

# %%
# Power Transformer

from sklearn.preprocessing import PowerTransformer
powertrns = PowerTransformer(method = 'yeo-johnson', standardize = True)
transformed = powertrns.fit_transform(skewddf)
transformed
# Out:
# array([[-0.6835812 , -0.54254271],
#        [-1.41102074, -1.40042349],
#        [-0.04541034,  0.03792235],
#        ...,
#        [ 0.65170897,  0.70646222],
#        [ 0.92651374,  0.83819639],
#        [ 1.97171906,  1.85540416]])

# %%
# check skewness
transformed = pd.DataFrame(transformed, columns = skewddf.columns) #this is to convert numpy array to dataframe
transformed.skew()
# Out:
# Length     -0.082999
# Diameter   -0.080963
# dtype: float64

# %%
out.reset_index(drop = True, inplace = True)
transformed.index = out.index
out[skew] = transformed[skew]
out
# Out:
#         Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    -0.683581 -0.542543   0.095        0.5140          0.2245
# 1    -1.411021 -1.400423   0.090        0.2255          0.0995
# 2    -0.045410  0.037922   0.135        0.6770          0.2565
# 3    -0.798788 -0.542543   0.125        0.5160          0.2155
# 4    -1.529910 -1.473662   0.080        0.2050          0.0895
# ...        ...       ...     ...           ...             ...
# 4024  0.290213  0.391080   0.165        0.8870          0.3700
# 4025  0.545706  0.270360   0.135        0.9660          0.4390
# 4026  0.651709  0.706462   0.205        1.1760          0.5255
# 4027  0.926514  0.838196   0.150        1.0945          0.5310
# 4028  1.971719  1.855404   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4024          0.2390        0.2490     11
# 4025          0.2145        0.2605     10
# 4026          0.2875        0.3080      9
# 4027          0.2610        0.2960     10
# 4028          0.3765        0.4950     12
#
# [4029 rows x 8 columns]

# %%
out.skew()
# Out:
# Length           -0.082999
# Diameter         -0.080963
# Height           -0.243246
# Whole weight      0.334719
# Shucked weight    0.458771
# Viscera weight    0.437599
# Shell weight      0.349333
# Rings             0.725901
# dtype: float64

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()
scaled_x = scaler.fit_transform(out)
scaled_x
# Out:
# array([[-0.6835812 , -0.54254271, -1.16590127, ..., -0.72241757,
#         -0.63069126,  1.8372675 ],
#        [-1.41102074, -1.40042349, -1.30151111, ..., -1.23041555,
#         -1.25608841, -0.95567718],
#        [-0.04541034,  0.03792235, -0.08102253, ..., -0.33053341,
#         -0.16164339, -0.25744101],
#        ...,
#        [ 0.65170897,  0.70646222,  1.81751525, ...,  1.08218478,
#          0.60446812, -0.25744101],
#        [ 0.92651374,  0.83819639,  0.32580699, ...,  0.82576675,
#          0.51065855,  0.09167707],
#        [ 1.97171906,  1.85540416,  1.54629556, ...,  1.94336231,
#          2.06633396,  0.78991324]])

# %%
m = MinMaxScaler()
m_m_scaled_x = m.fit_transform(x)
m_m_scaled_x
# Out:
# array([[0.51351351, 0.5210084 , 0.07589286, ..., 0.        , 0.        ,
#         1.        ],
#        [0.37162162, 0.35294118, 0.07142857, ..., 0.        , 0.        ,
#         1.        ],
#        [0.61486486, 0.61344538, 0.11160714, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.70945946, 0.70588235, 0.17410714, ..., 0.        , 0.        ,
#         1.        ],
#        [0.74324324, 0.72268908, 0.125     , ..., 1.        , 0.        ,
#         0.        ],
#        [0.85810811, 0.84033613, 0.16517857, ..., 0.        , 0.        ,
#         1.        ]])

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
# Adding value of 1.5 to every element of column "Rings" so that we get the age and adding new column age

age = y.add(1.5)
age
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Rings, Length: 4177, dtype: float64

# %% [markdown]
# Feature selection

# %%
from sklearn.feature_selection import SelectKBest, f_classif

bestfeat = SelectKBest (score_func = f_classif, k=10)

fit = bestfeat.fit(x,age)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

fit = bestfeat.fit(x,age)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
dfcolumns.head()

featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(10,'Score'))
# Out:
#           Feature       Score
# 7           Rings         inf
# 1        Diameter  196.436105
# 0          Length  188.509425
# 6    Shell weight  147.236946
# 2          Height  124.698676
# 3    Whole weight  113.712340
# 5  Viscera weight  103.721438
# 4  Shucked weight   80.797677
# 9           Sex_I   68.870477
# 8           Sex_F   15.783520

# %% [markdown]
# Data Modeling

# %%
# Regression Model Building

x_train,x_test,y_train,y_test = train_test_split(m_m_scaled_x,age,test_size = .31, random_state = 1)
lr = LinearRegression()
rf = RandomForestRegressor()
sv = SVR()
r = Ridge()
# Traing all the models
lr.fit(x_train,y_train)
rf.fit(x_train,y_train)
sv.fit(x_train,y_train)
r.fit(x_train,y_train)
# Out:
# Ridge()

# %%
# Linear Regression Model

y_lr_pred = lr.predict(x_test)

# Checking R2 Score

print(" R2 Score of Linear Regression : ", r2_score(y_test,y_lr_pred))

# Checking mean squared error

print(" Mean squared error of Linear Regression : ", mean_squared_error(y_test,y_lr_pred))
# Out:
#  R2 Score of Linear Regression :  1.0
#  Mean squared error of Linear Regression :  1.0780433024180308e-27

# %%
# Ridge Regression Model

y_r_pred = r.predict(x_test)

# Checking R2 score

print(" R2 Score of Ridge Regression : ",r2_score(y_test,y_r_pred))

# Checking mean squared error

print(" Mean Squarred error of Ridge Regression : ",mean_squared_error(y_test,y_r_pred))
# Out:
#  R2 Score of Ridge Regression :  0.9987772263325986
#  Mean Squarred error of Ridge Regression :  0.01223214063516673

# %%
# Random Forest Regression Model

y_rf_pred = rf.predict(x_test)
# Checking R2 Score

print(" R2 Score of Random Forest Regression:", r2_score(y_test,y_rf_pred))

# checking mean squared error

print(" Mean Squarred error of Random Forest Regression:", mean_squared_error(y_test,y_rf_pred))
# Out:
#  R2 Score of Random Forest Regression: 0.9998798502231423
#  Mean Squarred error of Random Forest Regression: 0.0012019305019305006

# %%
# Support Vector Regression Model

y_sv_pred = sv.predict(x_test)

# Checking R2 Score

print(" R2 Score of SVM Regression:",r2_score(y_test,y_sv_pred))

# checking mean squared error

print(" Mean squared error of SVM Regression:",mean_squared_error (y_test,y_sv_pred))
# Out:
#  R2 Score of SVM Regression: 0.9953764926683322
#  Mean squared error of SVM Regression: 0.046251725414460806

# %% [markdown]
# Cross Validation Score

# %%
print("Linear Regression Model:",cross_val_score(lr,m_m_scaled_x,age,cv = ShuffleSplit(5)).mean())
print("Ridge Regression Model:",cross_val_score(r,m_m_scaled_x,age,cv = ShuffleSplit(5)).mean())
print("Random Forest Regression Model:",cross_val_score(rf,m_m_scaled_x,age,cv = ShuffleSplit(5)).mean())
print("SV Regression Model:",cross_val_score(sv,m_m_scaled_x,age,cv = ShuffleSplit(5)).mean())
# Out:
# Linear Regression Model: 1.0
# Ridge Regression Model: 0.9993272159440894
# Random Forest Regression Model: 0.9998698787884208
# SV Regression Model: 0.995850072024633

# %% [markdown]
# Hyperparameter tuning

# %%
parameter = {'n_estimators':[30,60],
             'max_depth':[10,20,40],
             'min_samples_leaf':[5,10,20],
             'min_samples_split':[5,10],
             'criterion':['mse','mae'],
             'max_features':["auto","sqrt","log2"]}
Gridcv = GridSearchCV(RandomForestRegressor(),parameter, cv=5,n_jobs = -1,verbose = 1)
Gridcv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   41.9s

# %%
Gridcv.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 20,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 30}

# %%
Best_mod = RandomForestRegressor(n_estimators = 60,criterion = 'mse',max_depth = 40,max_features = 'auto',min_samples_leaf = 10,min_samples_split = 10)
Best_mod.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=40, min_samples_leaf=10, min_samples_split=10,
#                       n_estimators=60)

# %%
rf_pred = Best_mod.predict(x_test)
acc = r2_score(y_test,rf_pred)
print(acc*100)
# Out:
# 99.9469347208984

# %% [markdown]
# Save the Model

# %%
import pickle

filename = 'Abalone.pkl'
pickle.dump(Best_mod,open(filename, 'wb'))

loaded_model = pickle.load(open(filename, 'rb'))
loaded_model.predict(x_test)
# Out:
# array([11.5,  9.5, 10.5, ...,  9.5, 14.5, 11.5])

# %%
# Load the Model
# Predicting some of the X_test results and matching it with true i.e. y_test values using Random Forest.

a = np.array(y_test)
predicted = np.array(Best_mod.predict(x_test))
df_con = pd.DataFrame({"orginal":a, "predicted":predicted}, index = range(len(a)))
df_con
# Out:
#       orginal  predicted
# 0        11.5       11.5
# 1         9.5        9.5
# 2        10.5       10.5
# 3        11.5       11.5
# 4        17.5       17.5
# ...       ...        ...
# 1290     14.5       14.5
# 1291     14.5       14.5
# 1292      9.5        9.5
# 1293     14.5       14.5
# 1294     11.5       11.5
#
# [1295 rows x 2 columns]

# %% [markdown]
# As we can see, the predicted and the true values match around 100%.
